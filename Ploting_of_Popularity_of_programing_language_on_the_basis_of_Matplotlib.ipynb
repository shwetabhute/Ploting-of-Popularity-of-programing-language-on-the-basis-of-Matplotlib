# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetabhute/Ploting-of-Popularity-of-programing-language-on-the-basis-of-Matplotlib/blob/main/Ploting_of_Popularity_of_programing_language_on_the_basis_of_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['java','Python','PHP','Javascript','C#','C++'])
y = np.array([22.2, 17.6, 8.8, 8, 7.7, 6.7])
plt.title("Popularity of programin Languages Worldwide,Oct 2017compared to a year ago")
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.plot(x, y)
plt.bar(x,y)
plt.grid()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.minorticks_on()
plt.show()
